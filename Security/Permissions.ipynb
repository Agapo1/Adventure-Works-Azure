# %%
# %sql

GRANT USAGE ON CATALOG adventure_works TO `DataEngineers`;
GRANT USAGE ON CATALOG adventure_works TO `DataAnalysts`;
GRANT USAGE ON CATALOG adventure_works TO `Admins`;


GRANT ALL PRIVILEGES ON SCHEMA adventure_works.bronze TO `DataEngineers`;


GRANT ALL PRIVILEGES ON SCHEMA adventure_works.silver TO `DataEngineers`;
GRANT SELECT ON SCHEMA adventure_works.silver TO `DataAnalysts`;

GRANT SELECT ON SCHEMA adventure_works.golden TO `DataAnalysts`;
GRANT ALL PRIVILEGES ON SCHEMA adventure_works.golden TO `Admins`;


GRANT SELECT ON TABLE adventure_works.golden.fact_sales TO `DataAnalysts`;
