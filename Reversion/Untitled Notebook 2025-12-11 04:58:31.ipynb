# %%
# %sql

REVOKE SELECT ON TABLE adventure_works.golden.fact_sales FROM `DataAnalysts`;

REVOKE ALL PRIVILEGES ON SCHEMA adventure_works.golden FROM `Admins`;
REVOKE SELECT ON SCHEMA adventure_works.golden FROM `DataAnalysts`;

REVOKE ALL PRIVILEGES ON SCHEMA adventure_works.silver FROM `DataEngineers`;
REVOKE SELECT ON SCHEMA adventure_works.silver FROM `DataAnalysts`;

REVOKE ALL PRIVILEGES ON SCHEMA adventure_works.bronze FROM `DataEngineers`;

REVOKE USAGE ON CATALOG adventure_works FROM `DataEngineers`;
REVOKE USAGE ON CATALOG adventure_works FROM `DataAnalysts`;
REVOKE USAGE ON CATALOG adventure_works FROM `Admins`;
